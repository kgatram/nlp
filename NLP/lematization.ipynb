# %%
import nltk
import spacy
nltk.__version__
# Out:
# '3.8.1'

# %%
from nltk import PorterStemmer
stemmer = PorterStemmer()

# %%
lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']
for word in lst_words:
  print(word, "\tstem=", stemmer.stem(word))
# Out:
# running 	stem= run
# painting 	stem= paint
# walking 	stem= walk
# dressing 	stem= dress
# likely 	stem= like
# children 	stem= children
# whom 	stem= whom
# good 	stem= good
# ate 	stem= ate
# fishing 	stem= fish

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(' '.join(lst_words))
for word in doc:
  print(word,  word.lemma_, word.lemma)
# Out:
# running run 12767647472892411841
# painting paint 16929211676819693673
# walking walk 1674876016505392235
# dressing dress 12815368344456308931
# likely likely 6740298879949941214
# children child 737253710922290542
# whom whom 685434301945620124
# good good 5711639017775284443
# ate eat 9837207709914848172
# fishing fishing 10959402079719336560

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %% [markdown]
# Customizing Lemmatizer

# %%
ar = nlp.get_pipe('attribute_ruler')
ar.add([[{'TEXT':'Bro'}],[{'TEXT':'Brah'}]], {'LEMMA':'Brother'})
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")
for token in doc:
  print(token, token.lemma_)
# Out:
# Bro Brother
# , ,
# you you
# wanna wanna
# go go
# ? ?
# Brah Brother
# , ,
# do do
# n't not
# say say
# no no
# ! !
# I I
# am be
# exhausted exhaust

# %%
doc[6], doc[6].lemma_
# Out:
# (Brah, 'Brother')

# %%
text = """Latha is very multi talented girl.She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
"""

# %%
from nltk.tokenize import NLTKWordTokenizer
lst_words=NLTKWordTokenizer().tokenize(text)
' '.join([stemmer.stem(word) for word in lst_words])
# Out:
# 'latha is veri multi talent girl. she is good at mani skill like danc , run , sing , playing.sh also like eat pav bhagi. she ha a habit of fish and swim too.besid all thi , she is a wonder at cook too .'

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
# for word in doc:
#   print(word, word.lemma_)
print('Original:\n', text)
print('Lematization:')
print(' '.join([word.lemma_ for word in doc]))
# Out:
# Original:
#  Latha is very multi talented girl. She is good at many skills like dancing, running, singing, playing.She also likes eating Pav Bhagi. she has a
# habit of fishing and swimming too.Besides all this, she is a wonderful at cooking too.
#
# Lematization:
# Latha be very multi talented girl . she be good at many skill like dancing , running , singing , play . she also like eat Pav Bhagi . she have a
#  habit of fishing and swim too . besides all this , she be a wonderful at cook too .
